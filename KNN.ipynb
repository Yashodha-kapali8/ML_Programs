# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashodha-kapali8/ML_Programs/blob/main/KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PROGRAM 5:**
#
# Develop a program to implement k-Nearest Neighbour algorithm to classify the randomly generated 100 values of x in the range of [0,1]. Perform the following based on dataset generated.
#
# a) Label the first 50 points {x1,……,x50} as follows: if (xi ≤ 0.5), then xi ∊ Class1, else xi ∊ Class1
# b) Classify the remaining points, x51,……,x100 using KNN. Perform this for k=1,2,3,4,5,20,30

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

#  Generate 100 random values in [0,1]
np.random.seed(42)
x = np.random.rand(100).reshape(-1, 1)

# %%
#  Label first 50 values
y_train = np.array([1 if xi <= 0.5 else 2 for xi in x[:50].flatten()])

# Split data
X_train = x[:50]
X_test = x[50:]

# Try different k values
k_values = [1, 2, 3, 4, 5, 20, 30]

# %%
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)

    print(f"\nResults for k = {k}:")
    for i in range(len(X_test)):
        print(f"x[{50+i}] = {X_test[i][0]:.3f} --> Predicted Class: {y_pred[i]}")

    # Plotting
    plt.figure(figsize=(10, 3))
    # Plot training points
    plt.scatter(X_train, [1]*len(X_train), c=['blue' if y==1 else 'red' for y in y_train], label='Train (Known Class)', s=80, marker='o')
    # Plot test predictions
    plt.scatter(X_test, [1.05]*len(X_test), c=['blue' if y==1 else 'red' for y in y_pred], label='Test (Predicted)', s=80, marker='x')

    plt.title(f"k-NN Classification (k = {k})")
    plt.yticks([])
    plt.xlabel("x value (in [0,1])")
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.2), ncol=2)
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# Results for k = 1:
# x[50] = 0.970 --> Predicted Class: 2
# x[51] = 0.775 --> Predicted Class: 2
# x[52] = 0.939 --> Predicted Class: 2
# x[53] = 0.895 --> Predicted Class: 2
# x[54] = 0.598 --> Predicted Class: 2
# x[55] = 0.922 --> Predicted Class: 2
# x[56] = 0.088 --> Predicted Class: 1
# x[57] = 0.196 --> Predicted Class: 1
# x[58] = 0.045 --> Predicted Class: 1
# x[59] = 0.325 --> Predicted Class: 1
# x[60] = 0.389 --> Predicted Class: 1
# x[61] = 0.271 --> Predicted Class: 1
# x[62] = 0.829 --> Predicted Class: 2
# x[63] = 0.357 --> Predicted Class: 1
# x[64] = 0.281 --> Predicted Class: 1
# x[65] = 0.543 --> Predicted Class: 2
# x[66] = 0.141 --> Predicted Class: 1
# x[67] = 0.802 --> Predicted Class: 2
# x[68] = 0.075 --> Predicted Class: 1
# x[69] = 0.987 --> Predicted Class: 2
# x[70] = 0.772 --> Predicted Class: 2
# x[71] = 0.199 --> Predicted Class: 1
# x[72] = 0.006 --> Predicted Class: 1
# x[73] = 0.815 --> Predicted Class: 2
# x[74] = 0.707 --> Predicted Class: 2
# ...
